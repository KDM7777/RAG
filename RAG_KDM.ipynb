# %% [markdown]
# <a href="https://colab.research.google.com/github/KDM7777/RAG/blob/main/RAG_KDM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U langchain langchain-community langchain-openai langchainhub chromadb
# Out:
# WARNING: Ignoring invalid distribution ~penai (/usr/local/lib/python3.12/dist-packages)
# ...
#   Using cached openai-2.41.0-py3-none-any.whl.metadata (32 kB)
# ...
# Using cached openai-2.41.0-py3-none-any.whl (1.4 MB)
# WARNING: Ignoring invalid distribution ~penai (/usr/local/lib/python3.12/dist-packages)
# ...

# %%
import langchain
import chromadb

print("LangChain:", langchain.__version__)
print("ChromaDB:", chromadb.__version__)
# Out:
# LangChain: 1.3.4
# ChromaDB: 1.5.9

# %%
from google.colab import userdata
import os
os.environ['OPEN_API_KEY'] = userdata.get('OPEN_API')

# %%
from langchain_community.document_loaders import WebBaseLoader
loader = WebBaseLoader(web_path=["https://oursrmap.purlyedit.in/login_history.php"])
docs = loader.load()
print(docs)
# Out:
# /tmp/ipykernel_1833/3728565494.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import WebBaseLoader
# WARNING:langchain_community.utils.user_agent:USER_AGENT environment variable not set, consider setting it to identify your requests.
# ...

# %%
# !pip install -U langchain-text-splitters

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
)

splits = text_splitter.split_documents(docs)

# %%
print(len(splits))
# Out:
# 7

# %%
# !pip install -U langchain-openai langchain-community chromadb openai

# %%
from google.colab import userdata
import os

os.environ["OPENAI_API_KEY"] = userdata.get("OPEN_API")
print("API Key Loaded Successfully")
# Out:
# API Key Loaded Successfully

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="openai/gpt-4o-mini",
    base_url="https://openrouter.ai/api/v1",
    api_key=os.environ["OPENAI_API_KEY"]
)

response = llm.invoke("what about you?")
print(response.content)
# Out:
# I'm here to assist you with information, answer questions, provide explanations, and help with a variety of topics. What would you like to know or discuss?

# %%
# !pip install -U sentence-transformers

# %%
from langchain_community.vectorstores import Chroma
from langchain_community.embeddings import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

vectorstore = Chroma.from_documents(
    documents=splits,
    embedding=embeddings,
    collection_name="new_collection"
)

print("Chunks:", len(splits))
print("Stored:", vectorstore._collection.count())
# Out:
# /tmp/ipykernel_1833/4203609072.py:4: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:112: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...

# %%
print(vectorstore._collection.get())
# Out:
# {'ids': ['b00ff06a-eb5e-487a-b8bc-bf1fe3f61ba3', 'a02a0eb8-c63c-4036-b310-e422362402b3', '21f60a3d-7c76-4418-8e3a-18b4c5ccca83', '792d4c60-57aa-4957-b0f6-535c39a1891d', '0a7cbdf6-ddfc-4757-97fb-fd0ef3f209aa', 'd5289ade-bb3c-4862-81b2-bfb249ee29a0', 'd026eccb-cf6c-4b65-a1c7-1ba879689b7b'], 'embeddings': None, 'documents': ["Login History\n\n\n\n\n\n\nLogin Summary\n\n\n\n \r\n                Thursday, June 4, 2026: \r\n                23 users\n\n\n\n\n\n\n\n\n\n \r\n                Wednesday, June 3, 2026: \r\n                61 users\n\n\n\n\n\n\n\n\n\n \r\n                Tuesday, June 2, 2026: \r\n                67 users\n\n\n\n\n\n\n\n\n\n \r\n                Monday, June 1, 2026: \r\n                267 users\n\n\n\n\n\n\n\n\n\n \r\n                Sunday, May 31, 2026: \r\n                51 users\n\n\n\n\n\n\n\n\n\n \r\n                Saturday, May 30, 2026: \r\n                51 users\n\n\n\n\n\n\n\n\n\n \r\n                Friday, May 29, 2026: \r\n                61 user
# ...

# %%
print(
    "\nCollection 1 - ",
    vectorstore._collection.get(
        ids=['75252957-7961-44c3-9a6d-3fd52806a9ec'],
        include=["embeddings", "documents"]
    )
)
# Out:
# Collection 1 -  {'ids': [], 'embeddings': array([], dtype=float64), 'documents': [], 'uris': None, 'included': ['embeddings', 'documents'], 'data': None, 'metadatas': None}

# %%
retriever = vectorstore.as_retriever()

# %%
# !pip install -U langchainhub

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="openai/gpt-4o-mini",
    base_url="https://openrouter.ai/api/v1",
    api_key=os.environ["OPENAI_API_KEY"]
)

# %%
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser

# %%
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_template("""
Answer the question based only on the following context.

Context:
{context}

Question:
{question}

Answer:
""")

# %%
rag_chain = (
    {
        "context": retriever | format_docs,
        "question": RunnablePassthrough()
    }
    | prompt
    | llm
    | StrOutputParser()
)

# %%
import warnings
warnings.filterwarnings("ignore")

response = rag_chain.invoke("What is this website about?")
print("\nANSWER:\n")
print(response)
# Out:
# ANSWER:
#
# The website appears to provide a login history and summary for users accessing a particular service or platform. It tracks the number of unique users logging in on specific dates, along with details about individual logins, including user names, identification numbers, and the time since they logged in.

# %%
import warnings
warnings.filterwarnings("ignore")

response = rag_chain.invoke("give me latest login 15 user names with register numbers?")
print("\nANSWER:\n")
print(response)
# Out:
# ANSWER:
#
# 1. KEERTHANA MUNDLAPALLI - AP25110010819
# 2. PRITHVISREE NADIPUDI - AP25110020107
# 3. PRITHVISREE NADIPUDI - AP25110020107
# 4. YASH CHAUBEY - AP25110010525
# 5. K DURGA MANIKANTA - AP24110010878
# 6. RISHITHA GUJJULA - AP25110010483
# 7. ABDULKALAM PATAN - AP24110010912
# 8. SIRI BODDU - AP25110071109
# 9. TEJESWAR SINGIRIGARI - AP25110090114
# 10. JASWANTH GANIPINENI - AP25110070733
# 11. PRAGNESH YEDRU - AP25110080068
# 12. AFREED K - AP25110010693
# 13. NANI BALAGA - AP24110011622
# 14. ABDULKALAM PATAN - AP24110010912
# 15. SIRI BODDU - AP25110020241
